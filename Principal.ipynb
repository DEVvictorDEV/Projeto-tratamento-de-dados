# %%
import pandas as pd

# %%
dados = pd.read_csv('C:\\Users\\victo\\Documents\\GitHub\\Projeto-tratamento-de-dados\\movies_1980_2020_30k.csv', sep=',')
dados
# Out:
#                       Title            Director        Genre Release Date  \
# 0       Key entire popular.      Anthony Becker       Horror   1981-05-12
# 1       Gun husband reveal.     William Johnson  Documentary   2016-06-13
# 2              Crime cover.              Amy Le        Drama   1988-03-22
# 3                Challenge.     Andrea Martinez      Romance   2013-04-01
# 4              Close study.     Michael Rodgers      Fantasy   2012-10-18
# ...                     ...                 ...          ...          ...
# 29995             Daughter.      Richard Nelson      Romance   2007-03-12
# 29996               Simply.    Jeffrey Hatfield      Fantasy   2011-08-16
# 29997   Also authority nor.          Ryan Brown       Action   1998-05-07
# 29998    Total report upon.  Melissa Stephenson       Comedy   2008-06-06
# 29999  Shoulder above note.       Cathy Edwards       Horror   2015-10-19
#
#        Duration  Rating
# 0           102     6.8
# 1            92     7.6
# 2           144     5.5
# 3           161     2.0
# 4           177     3.7
# ...         ...     ...
# 29995       177     8.0
# 29996       126     5.7
# 29997        73     4.9
# 29998       145     6.9
# 29999        85     6.3
#
# [30000 rows x 6 columns]

# %%
Qtd = dados.value_counts() # Quantidade de cada linha verifica se há alguma repetida
Qtd
# Out:
# Title                    Director             Genre      Release Date  Duration  Rating
# A admit despite.         Chelsea Leon         Adventure  2010-04-26    166       1.7       1
# Professional painting.   Kelly Stephenson     Adventure  2017-06-01    107       6.4       1
# Professional town city.  John Miller          Fantasy    1982-02-03    104       9.3       1
# Professional this.       Crystal Phillips     Thriller   1993-03-20    164       3.4       1
# Professional third.      Travis Pearson       Comedy     1988-01-22    66        3.2       1
#                                                                                           ..
# Form area president.     Elizabeth Poole      Sci-Fi     1987-04-01    157       3.2       1
# Form along.              Ronald Smith         Comedy     2015-09-20    152       5.9       1
# Form allow these above.  Clinton Christensen  Comedy     2014-08-06    144       3.8       1
# Form add public.         Jonathan Riley       Sci-Fi     1991-06-19    110       7.6       1
# Yourself.                Stacey Green         Romance    1990-05-28    128       3.7       1
# Name: count, Length: 30000, dtype: int64

# %%
empty_columns = dados.isnull().all(axis=0) #Verifica se há alguma linha (axis=0) está vazia
print(empty_columns)
# Out:
# Title           False
# Director        False
# Genre           False
# Release Date    False
# Duration        False
# Rating          False
# dtype: bool

# %%
dados.dtypes #Checar o tipo de dados
# Out:
# Title            object
# Director         object
# Genre            object
# Release Date     object
# Duration          int64
# Rating          float64
# dtype: object

# %%
dados["Release Date"] =pd.to_datetime(dados["Release Date"])

# %%
dados.convert_dtypes().dtypes
# Out:
# Title           string[python]
# Director        string[python]
# Genre           string[python]
# Release Date    datetime64[ns]
# Duration                 Int64
# Rating                 Float64
# dtype: object

# %%
#dados.sort_values('Title') # coloca em ordem alfabetica de acordo com a coluna title
Tabela_Formatada = dados.sort_values('Title')
Tabela_Formatada
# Out:
#                            Title             Director      Genre Release Date  \
# 11038           A admit despite.         Chelsea Leon  Adventure   2010-04-26
# 8770                    A agree.  Christopher Johnson   Thriller   1995-03-30
# 3309             A article well.      Joseph Anderson    Fantasy   2005-11-28
# 14954                    A book.      Sherry Mitchell      Drama   2014-07-22
# 23934               A build bar.        Shaun Ballard   Thriller   2017-08-26
# ...                          ...                  ...        ...          ...
# 29744  Yourself yourself minute.       Stephanie Cruz    Fantasy   1988-08-24
# 22810                  Yourself.        Jamie Patrick     Sci-Fi   2015-01-10
# 10723                  Yourself.      Michael Aguilar     Horror   2006-07-02
# 20362                  Yourself.        Lauren Taylor     Comedy   1988-08-05
# 28326                  Yourself.         Stacey Green    Romance   1990-05-28
#
#        Duration  Rating
# 11038       166     1.7
# 8770        174     1.7
# 3309        174     6.1
# 14954       165     9.8
# 23934       124     2.9
# ...         ...     ...
# 29744       100     4.4
# 22810        69     2.5
# 10723       112     4.3
# 20362        91     8.5
# 28326       128     3.7
#
# [30000 rows x 6 columns]

# %%
#Utilizar os dados para algo 
#1 Diretor e Nota para os melores filmes

MelhoresFilmes = Tabela_Formatada.nlargest(20,'Rating')#Função que pode retornar os maiores valores de acordo com o primeiro parametro (5,'coluna')
MelhoresFilmes
# Out:
#                            Title            Director      Genre Release Date  \
# 21989      According film radio.        Edward Leach    Romance   1987-12-09
# 13052                  Activity.    Tiffany Oconnell   Thriller   1988-09-21
# 27435              Along police.       Tracie Miller     Comedy   1994-06-28
# 12671       Already total place.          Connor Lee    Fantasy   1988-09-06
# 5662              Always career.      Kristina Smith      Drama   2019-03-29
# 2799                     Amount.        Kevin Hudson     Action   2009-02-04
# 18742         Animal collection.       Crystal Roman  Adventure   2002-05-09
# 8827              Another prove.         John Garcia     Action   1986-03-28
# 23337    Arm small realize step.       Hannah Krause     Sci-Fi   1999-11-25
# 16804                  At wrong.        Morgan Stein   Thriller   2010-01-18
# 18069        Before safe detail.        Mary Lambert   Thriller   1984-10-19
# 2974                Behind full.          Ashley Cox   Thriller   1990-12-06
# 20668         Black bar control.         Adam Porter     Action   1986-02-04
# 28857              Bring leader.      Isabel Johnson     Horror   1993-12-16
# 3653          Card behind truth.         Amy Stewart     Sci-Fi   1998-02-24
# 2135             Case lead hair.         Amy Delgado     Action   2020-03-24
# 15768                 Challenge.  Mr. Jesus Robinson     Comedy   1993-07-07
# 16578             Civil similar.      Laura Mcdaniel      Drama   2003-03-31
# 1065                Close third.    Richard Hatfield      Drama   1999-02-23
# 25541  Common physical security.       Julie Morales    Fantasy   2009-02-01
#
#        Duration  Rating
# 21989        98    10.0
# 13052       155    10.0
# 27435        67    10.0
# 12671        91    10.0
# 5662        167    10.0
# 2799        139    10.0
# 18742        80    10.0
# 8827        113    10.0
# 23337       171    10.0
# 16804       179    10.0
# 18069       146    10.0
# 2974         90    10.0
# 20668       126    10.0
# 28857        91    10.0
# 3653        178    10.0
# 2135         83    10.0
# 15768       164    10.0
# 16578       135    10.0
# 1065         63    10.0
# 25541       133    10.0

# %%
#Mostrar os generos de filmes
qtd = Tabela_Formatada[Tabela_Formatada["Rating"]== 10]
qtd #Mostra todos os filmes com nota 10
Generos_Favoritos = qtd["Genre"].value_counts()
Generos_Favoritos # Mostra todos os filmes nota 10 por genero
# Out:
# Genre
# Action         23
# Comedy         21
# Thriller       19
# Adventure      17
# Fantasy        16
# Drama          16
# Romance        15
# Sci-Fi         10
# Documentary    10
# Horror          6
# Name: count, dtype: int64
